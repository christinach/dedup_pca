# %% [markdown]
# # Find similarities and duplicates
# ## Text Embeddings
# Use the [SentenceTransformers (SBERT)](https://sbert.net/) to create text embeddings from the following marc fields:
# ```
# - id: 001,
# - title: 245$a, 245$b, 245$p, 245$f
# - pagination: 300$a
# - publication year: 008[7:11], 008[11:15], 264$c, 260$c
# - vernacular title: linked fields of 245
# - vernacular author: linked fields of 100, 110, 111
# - context title: 505$t
# - edition: 250$a
# - publisher name: 264$b, 260$b`
# ```
# As a first step we use the trained model `model_name="all-MiniLM-L6-v2"`.
#
# We parse the marcxml file and create a string from the values of the marc fields. We use this string to create text embeddings.We're saving the text embedding in a new json file that includes the text_embedding field and the record id.

# %%
# !pip3 install pymarc
# !pip3 install sentence-transformers
# !pip3 install pandas
# !pip3 install matplotlib

# %%
import tarfile
import pymarc
import glob
import os, tarfile, re, json
from pymarc import parse_xml_to_array
import string
from sentence_transformers import SentenceTransformer
import pandas as pd
import numpy as np
from marcxml_embedding_parser import MARCXMLEmbeddingParser
from ipca_on_embeddings import IPCAOnEmbeddings
from sample_embeddings_matrix import SampleEmbeddingsMatrix

# %%
marcxml_dir = "data_marcxml"
parser = MARCXMLEmbeddingParser();

# %%
parser.parse_scsb_update_files(input_dir=marcxml_dir, batch_size=10000)

# %%
parser.create_embedding_matrix()
# Out:
# Saved embedding matrix (with column names, no IDs): embeddings_matrix/scsb_update_batch_1_matrix.csv
# Saved embedding matrix (with column names, no IDs): embeddings_matrix/scsb_update_batch_2_matrix.csv
# Saved embedding matrix (with column names, no IDs): embeddings_matrix/scsb_update_batch_3_matrix.csv
# Saved embedding matrix (with column names, no IDs): embeddings_matrix/scsb_update_batch_4_matrix.csv
# Saved embedding matrix (with column names, no IDs): embeddings_matrix/scsb_update_batch_5_matrix.csv
# Saved embedding matrix (with column names, no IDs): embeddings_matrix/scsb_update_batch_6_matrix.csv

# %% [markdown]
# ## PCA (Principal Component Analysis)
#
# PCA enables dimensionality reduction. Text embeddings are represented as vectors in a multi-dimensional space. We employ Principal Component Analysis (PCA) to compute the number of components required to explain 95% of the variance within the data. PCA enables dimensionality reduction.
#
# To achieve this, we utilize Incremental Principal Component Analysis (IPCA), which allows for efficient processing of large datasets by incrementally updating the PCA model. We load the data in batches, specifically 10,000 records per file, to ensure manageable memory usage and to calculate the Explained Variance Ratio and the Cumulative Explained Variance.
#
# For similarity detection and duplicate identification, we apply the Euclidean distance metric. The threshold for determining similarity and duplication is adjusted based on the calculated distance ranges. The smaller we set the Euclidean distance, the more identical records we expect to identify.

# %%
ipca_obj = IPCAOnEmbeddings()

# %%
SampleEmbeddingsMatrix().create_sample()
# Out:
# Batch files found: ['embeddings_matrix/scsb_update_batch_1_matrix.csv', 'embeddings_matrix/scsb_update_batch_2_matrix.csv', 'embeddings_matrix/scsb_update_batch_3_matrix.csv', 'embeddings_matrix/scsb_update_batch_4_matrix.csv', 'embeddings_matrix/scsb_update_batch_5_matrix.csv', 'embeddings_matrix/scsb_update_batch_6_matrix.csv']
# Saved 10000 sampled rows to embeddings_matrix/sample_10000_matrix.csv

# %%
n_components = ipca_obj.calculate_number_of_components_with_pca()
# Out:
# Batch files found: ['embeddings_matrix/scsb_update_batch_1_matrix.csv', 'embeddings_matrix/scsb_update_batch_2_matrix.csv', 'embeddings_matrix/scsb_update_batch_3_matrix.csv', 'embeddings_matrix/scsb_update_batch_4_matrix.csv', 'embeddings_matrix/scsb_update_batch_5_matrix.csv', 'embeddings_matrix/scsb_update_batch_6_matrix.csv']
# Saved 10000 sampled rows to embeddings_matrix/sample_10000_matrix.csv
# Number of components for 95.0% variance: 419

# %%
batch_size = 10000
batch_files = sorted(glob.glob("embeddings_matrix/scsb_update_batch_*_matrix.csv"))

# %%
ipca_obj.calculate_ipca(n_components=n_components, batch_size=batch_size)
ipca = ipca_obj.ipca_fit(
    n_components=n_components, batch_files=batch_files, batch_size=batch_size
)
# Out:
# 2026-03-20 12:39:32 Starting IncrementalPCA on embeddings...
# n_components: 8, n_features: 384, n_samples_first_batch: 8
# Fitting IPCA on embeddings_matrix/scsb_update_batch_1_matrix.csv
# Fitting IPCA on embeddings_matrix/scsb_update_batch_2_matrix.csv
# Fitting IPCA on embeddings_matrix/scsb_update_batch_3_matrix.csv
# Fitting IPCA on embeddings_matrix/scsb_update_batch_4_matrix.csv
# Fitting IPCA on embeddings_matrix/scsb_update_batch_5_matrix.csv
# Fitting IPCA on embeddings_matrix/scsb_update_batch_6_matrix.csv

# %%
tranformed_batches = ipca_obj.ipca_transform(batch_files=batch_files, ipca=ipca)
# Out:
# Transforming embeddings_matrix/scsb_update_batch_1_matrix.csv
# Transforming embeddings_matrix/scsb_update_batch_2_matrix.csv
# Transforming embeddings_matrix/scsb_update_batch_3_matrix.csv
# Transforming embeddings_matrix/scsb_update_batch_4_matrix.csv
# Transforming embeddings_matrix/scsb_update_batch_5_matrix.csv
# Transforming embeddings_matrix/scsb_update_batch_6_matrix.csv

# %%
X_ipca=ipca_obj.ipca_combine_transformed_batches(tranformed_batches, ipca)
# Out:
# Final IPCA shape: (23715, 8)
# IPCA transformed data (first 5 rows):
# [[-0.22645589 -0.30066217 -2.59726035 -0.16386305 -2.2808376  -0.16093047
#   -0.71889792  1.4074455 ]
#  [ 0.60766554 -1.35693678 -1.29139186 -1.11133238 -2.05525     2.79713053
#   -5.06163402  1.8467341 ]
#  [-1.12000929 -0.26486063  7.43630791 -0.79156743 -2.14381256 -0.7061269
#    1.3539872  -2.14671884]
#  [ 0.85648911 -5.13239729 -1.35101605 -0.3040594   0.77281467  0.66021714
#   -3.46036578  3.58353932]
#  [-0.3842222  -1.81945828 -0.93647906  5.89631044  1.33676362  0.31160074
#    4.60978232 -3.44232635]]
# Explained variance ratio (IPCA):
# [0.05003697 0.0418856  0.02427324 0.02101307 0.01956221 0.01777786
#  0.01578973 0.01392633]
# Cumulative explained variance (IPCA):
# [0.05003697 0.09192256 0.1161958  0.13720887 0.15677109 0.17454894
#  0.19033868 0.204265  ]

# %%
distances_ipca=ipca_obj.euclidean_distances_in_ipca_space(X_ipca=X_ipca)
# Out:
# Sample pairwise distances in IPCA space (first 5): [ 5.68047631 10.91380668  6.95279224 10.34606078  8.17747747]
# Max distance in IPCA space: 28.015087261411903
# Min distance in IPCA space (excluding zero): 2.384185791015625e-07

# %%
threshold_ipca=ipca_obj.threshold_ipca(distances_ipca=distances_ipca)
# Out:
# Automated threshold_ipca min_distance: 0.0001

# %%
ipca_obj.identify_duplicates(euclidean_distances_in_ipca_space=distances_ipca,threshold_ipca=threshold_ipca)
# Out:
# threshold_ipca: 0.0001
# Found 6 potential duplicate pairs in IPCA space.
# Duplicate pair indices and record IDs (IPCA):
# Pair: (539, 540) -> IDs: SCSB-9222960, SCSB-9223864
# Pair: (539, 549) -> IDs: SCSB-9222960, SCSB-9352657
# Pair: (540, 549) -> IDs: SCSB-9223864, SCSB-9352657
# Pair: (6253, 6489) -> IDs: SCSB-11082333, SCSB-11799661
# Sample pairwise distances in IPCA space (first 5): [ 5.68047631 10.91380668  6.95279224 10.34606078  8.17747747]
# Max distance in IPCA space: 28.015087261411903
# Min distance in IPCA space (excluding zero): 2.384185791015625e-07
